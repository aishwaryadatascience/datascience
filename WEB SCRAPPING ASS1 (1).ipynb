# %%
# !pip install bs4
# !pip install requests

# %%
#Answer 1

import requests
from bs4 import BeautifulSoup
import pandas as pd

#Send an HTTP GET request to wikipedia.org
url = "https://en.wikipedia.org/wiki/Main_Page"
response = requests.get(url)

#Check if the request was successful
if response.status_code ==200:
    #Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')
    
    #Find all header tags (h1, h2, h3, h4, h5, h6)
    header_tags = soup.find_all(['h1', 'h2', 'h3', 'h4', 'h5', 'h6'])
    
    #Extract the text from the header tags and store them in a list 
    header_texts = [tag.text.strip() for tag in header_tags]
    
    #Create a DataFrame from the extracted header texts
    df = pd.DataFrame({'Header':header_texts})
    
    #Display the DataFrame
    print(df)
    
else:
    print ("Failed to retrive the web page. Status code:", response.status_code)
# Out:
#                           Header
# 0                      Main Page
# 1           Welcome to Wikipedia
# 2  From today's featured article
# 3               Did you know ...
# 4                    In the news
# 5                    On this day
# 6       Today's featured picture
# 7       Other areas of Wikipedia
# 8    Wikipedia's sister projects
# 9            Wikipedia languages

# %%
#Answer3

import requests
from bs4 import BeautifulSoup
import pandas as pd

# Function to scrape and create a DataFrame for rankings
def scrape_icc_rankings(url):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Find the relevant table
        table = soup.find('table', class_='table')
        
        # Initialize lists to store data
        names = []
        matches = []
        points = []
        ratings = []

        # Find and extract data from the table
        for row in table.find_all('tr')[1:11]:  # Extract top 10 rows
            columns = row.find_all('td')
            if len(columns) == 5:  # Ensure the row has the expected number of columns
                name = columns[1].text.strip()
                match = columns[2].text.strip()
                point = columns[3].text.strip()
                rating = columns[4].text.strip()
                names.append(name)
                matches.append(match)
                points.append(point)
                ratings.append(rating)
        
        # Create a DataFrame
        df = pd.DataFrame({'Team': names, 'Matches': matches, 'Points': points, 'Rating': ratings})
        
        return df
    else:
        print(f"Failed to retrieve the web page. Status code: {response.status_code}")
        return None

# URLs for different rankings
odi_teams_url = "https://www.icc-cricket.com/rankings/mens/team-rankings/odi"
odi_batsmen_url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting"
odi_bowlers_url = "https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling"

# Scrape and create DataFrames
odi_teams_df = scrape_icc_rankings(odi_teams_url)
odi_batsmen_df = scrape_icc_rankings(odi_batsmen_url)
odi_bowlers_df = scrape_icc_rankings(odi_bowlers_url)

# Display DataFrames
if odi_teams_df is not None:
    print("Top 10 ODI Teams:")
    print(odi_teams_df)

if odi_batsmen_df is not None:
    print("\nTop 10 ODI Batsmen:")
    print(odi_batsmen_df)

if odi_bowlers_df is not None:
    print("\nTop 10 ODI Bowlers:")
    print(odi_bowlers_df)
# Out:
# Top 10 ODI Teams:
#                Team Matches Points Rating
# 0    Australia\nAUS      27  3,112    115
# 1     Pakistan\nPAK      27  3,102    115
# 2        India\nIND      40  4,558    114
# 3      England\nENG      28  2,942    105
# 4  South Africa\nSA      23  2,386    104
# 5   New Zealand\nNZ      31  3,110    100
# 6   Bangladesh\nBAN      33  3,107     94
# 7     Sri Lanka\nSL      37  3,448     93
# 8  Afghanistan\nAFG      21  1,687     80
# 9   West Indies\nWI      38  2,582     68
#
# Top 10 ODI Batsmen:
#                     Team Matches Points                         Rating
# 0             Babar Azam     PAK    863  898 v West Indies, 10/06/2022
# 1           Shubman Gill     IND    759     763 v Pakistan, 10/09/2023
# 2  Rassie van der Dussen      SA    745      796 v England, 19/07/2022
# 3           David Warner     AUS    739     880 v Pakistan, 26/01/2017
# 4            Imam-ul-Haq     PAK    735  815 v West Indies, 12/06/2022
# ...

# %%
#Answer4

import requests
from bs4 import BeautifulSoup
import pandas as pd

# Function to scrape and create a DataFrame for rankings
def scrape_icc_rankings(url):
    response = requests.get(url)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Find the relevant table
        table = soup.find('table', class_='table')
        
        # Initialize lists to store data
        names = []
        matches = []
        points = []
        ratings = []

        # Find and extract data from the table
        for row in table.find_all('tr')[1:11]:  # Extract top 10 rows
            columns = row.find_all('td')
            if len(columns) == 5:  # Ensure the row has the expected number of columns
                name = columns[1].text.strip()
                match = columns[2].text.strip()
                point = columns[3].text.strip()
                rating = columns[4].text.strip()
                names.append(name)
                matches.append(match)
                points.append(point)
                ratings.append(rating)
        
        # Create a DataFrame
        df = pd.DataFrame({'Team': names, 'Matches': matches, 'Points': points, 'Rating': ratings})
        
        return df
    else:
        print(f"Failed to retrieve the web page. Status code: {response.status_code}")
        return None

# URLs for different rankings
women_odi_teams_url = "https://www.icc-cricket.com/rankings/womens/team-rankings/odi"
women_odi_batting_url = "https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting"
women_odi_allrounder_url = "https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder"

# Scrape and create DataFrames
women_odi_teams_df = scrape_icc_rankings(women_odi_teams_url)
women_odi_batting_df = scrape_icc_rankings(women_odi_batting_url)
women_odi_allrounder_df = scrape_icc_rankings(women_odi_allrounder_url)

# Display DataFrames
if women_odi_teams_df is not None:
    print("Top 10 Women's ODI Teams:")
    print(women_odi_teams_df)

if women_odi_batting_df is not None:
    print("\nTop 10 Women's ODI Batting Players:")
    print(women_odi_batting_df)

if women_odi_allrounder_df is not None:
    print("\nTop 10 Women's ODI All-rounders:")
    print(women_odi_allrounder_df)
# Out:
# Top 10 Women's ODI Teams:
#                Team Matches Points Rating
# 0    Australia\nAUS      26  4,290    165
# 1      England\nENG      31  3,875    125
# 2  South Africa\nSA      26  3,098    119
# 3        India\nIND      30  3,039    101
# 4   New Zealand\nNZ      28  2,688     96
# 5   West Indies\nWI      29  2,743     95
# 6   Bangladesh\nBAN      17  1,284     76
# 7     Sri Lanka\nSL      12    820     68
# 8     Thailand\nTHA      13    883     68
# 9     Pakistan\nPAK      27  1,678     62
#
# Top 10 Women's ODI Batting Players:
#                    Team Matches Points                         Rating
# 0  Natalie Sciver-Brunt     ENG    801    803 v Australia, 18/07/2023
# 1           Beth Mooney     AUS    751      776 v England, 12/07/2023
# 2   Chamari Athapaththu      SL    743  758 v New Zealand, 03/07/2023
# 3       Laura Wolvaardt      SA    708    741 v Australia, 22/03/2022
# 4       Smriti Mandhana     IND    708      797 v England, 28/02/2019
# ...
